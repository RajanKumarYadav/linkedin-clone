# %% [markdown]
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
# RAJANKUMARYADAV
# MLOpsTechLead|AIArchitect|MachineLearningEngineer
# Bengaluru,Karnataka,India
# LinkedIn:https://www.linkedin.com/in/rajankumaryadav/|GitHub: https://github.com/RajanKumarYadav
# PROFESSIONALSUMMARY
# Results-drivenMLOpsTechLeadandAIArchitectwith12+yearsofhands-onexperiencedesigninganddeploying
# scalable,production-grademachinelearningsystems.ProventrackrecordofdeliveringUSD2.5M+incostsavings
# throughMLautomationandoperationalexcellence.Expertinend-to-endMLlifecyclemanagement,CI/CDpipelines,
# andcloudinfrastructure(Azure,Databricks).SpecializedinMLOps,modeldeployment,Kubernetesorchestration,andAI
# governance.Recognizedforreducingdeploymenttimeby90%andimprovingsystemreliabilityacrossenterprise
# environments.
# TECHNICALSKILLS
# MLOps&DevOps: MLOps,LLMOps,MLflow,DatabricksAssetBundles,Infrastructure-as-Code,Terraform,CI/CD(GitHub
# Actions),Git,Bitbucket,Docker,Kubernetes,ModelRegistry,FeatureStores,MLObservability,ModelMonitoring
# Cloud&DataPlatforms: MicrosoftAzure,AzureML,AzureDataFactory,AzureKubernetesService(AKS),Databricks,
# DeltaLiveTables,MinIO,AzureSQLDatabase,AzureDataLakeStorageGen2
# Programming&MLFrameworks: Python,NumPy,Pandas,Scikit-learn,TensorFlow,Keras,XGBoost,Flask,FastAPI,
# RESTfulAPIs,JSON
# ModelDeployment&Serving: SeldonCore,TensorFlowServing,DockerContainerization,KubernetesOrchestration,
# BatchInference,Real-timeInference,ModelVersioning,A/BTesting
# MachineLearning&AI: SupervisedLearning(Classification,Regression,NeuralNetworks,TimeSeries-ARIMA,LSTM),
# UnsupervisedLearning(Clustering,AssociationRules,DimensionalityReduction),DeepLearning,ModelOptimization,
# HyperparameterTuning,AutoML
# DataEngineering&Analytics: ETL/ELTPipelines,SQL,DataPreprocessing,FeatureEngineering,ExploratoryData
# Analysis(EDA),DataVisualization
# Leadership&Strategy: TechnicalTeamLeadership,Cross-functionalCollaboration,StakeholderManagement,Technical
# Strategy,Agile/ScrumMethodologies,Mentoring&Training,AIGovernance
# PROFESSIONALEXPERIENCE
# Architect-AI&MLEngineering
# Fractal Analytics, Bengaluru | July 2024 - Present (1.8 years)
# Client:BlueShieldofCalifornia
# • ArchitectedandimplementedInfrastructure-as-Code(IaC)forMLworkflowsusingDatabricksAssetBundles
# (DABs),enablingversion-controlleddeploymentofMLjobs,pipelines,andresourcesacrossdevelopment,
# staging,andproductionenvironmentswithstandardizedYAMLconfigurations.
# • Designedanddeployedmulti-environmentCI/CDpipelinearchitectureusingDatabricksAssetBundles,
# orchestratingseamlesspromotionofMLassetsacrossmultipleworkspaceswhilemaintainingenvironment-
# specificconfigurationsandensuring99.9%deploymentconsistency.
# • EstablishedmodularandreusableMLOpstemplatesforMLprojects,creatingstandardizedbestpracticesfor
# projectstructure,resourcedefinitions,anddeploymentpatternsthatreduceddeploymenttimeby90%and
# enabledrapidteamonboarding.• ImplementedunifieddeploymentstrategyforcompleteMLsolutions,bundlingDeltaLiveTablespipelines,
# scheduledjobs,MLflowexperiments,andmodelservingendpointsasatomicunitstoensuredependency
# managementandreproducibilityacrossenvironments.
# • EnhancedMLobservability,monitoring,andAIgovernancebyleveragingAssetBundleconfigurationsfor
# trackingmodellineage,experimentmetadata,projectcostoptimization,andresourceutilization,improving
# operationalefficiencyby40%.
# MachineLearningArchitect-MLOps
# HCL Software, Bengaluru | December 2021 - June 2024 (2.5 years)
# Client:VodafoneNetherlandsandEricsson
# • LedQoEOptimizationinitiativefor5GTelecomManagement,developingrobustdatapipelinesandMLmodels
# thatsavedapproximatelyUSD2.5millionannuallythroughoperationalgapanalysisandincreasedprofitability
# acrossfivebusinessunits.
# • DesignedanddeployedSmartAnalyticsApplicationfor5Gtelecomnetworks,implementingend-to-endML
# pipelinesusingMLOpsbestpracticesthatreducedturnaroundtime(TAT)to2daysanddecreaseddefectaging
# by53%.
# • OperationalizedMLmodelstocreate,publish,andconsumemultipleMLpipelinesusingCI/CDautomationwith
# Docker,Kubernetes,andBamboo,achieving95%deploymentsuccessrateandreducingmanualinterventionby
# 80%.
# • Engineereddatapreprocessing,MLtraining,andinferencepipelinesforlarge-scale5GtelemetrydatainAzure
# DataLakeStorageGen2andAzureSQLDatabase,processing10TB+ofperformancemetricsdatamonthly.
# • DevelopedFlask-basedMLapplicationsenablingbatchandonlineinferencefortime-seriesforecastingand
# prediction,serving500+APIrequestspersecondwithsub-100mslatency.
# • ImplementedmodelpackagingandhostingusingSeldonandTensorFlowServing,managingMinIOModel
# RegistryfordeploymentsacrossQA,staging,andproductionKubernetesclusters.
# • EstablishedcomprehensiveMLflow-basedexperimenttracking,logging,andmodelmonitoringframework,
# improvingmodelgovernanceandenablingdata-drivendecision-makingacrossMLteams.
# LeadDataScientist
# LTI Mindtree, Bengaluru | October 2020 - December 2021 (1.3 years)
# Client:Procter&Gamble
# • Leddatascienceinitiativesapplyingadvancedstatisticalmodelingtechniquesincludingclustering,classification,
# neuralnetworks,andregressionanalysistosolvecomplexbusinessproblemsanddrivestrategicdecision-
# making.
# • TranslatedbusinessgoalsintoactionableMLsolutionsthroughexploratorydataanalysis,featureengineering,
# andalgorithmdevelopment,delivering15+production-readymodelsacrossmultipledomains.
# • DesignedanddevelopedMLwebapplicationsusingFlaskframework,enablingnon-technicalstakeholdersto
# leveragepredictivemodelsthroughintuitiveinterfacesandautomatedreportingdashboards.
# DataScientist
# Cognizant Technology Solutions, Pune | November 2017 - October 2020 (3 years)
# Client:BankofAmerica
# • Designedandexecuteddataaggregationframeworksfromdiversesources,creatingreplicabledatapipelines
# thatreduceddatapreparationtimeby60%andimproveddataqualitymetrics.
# • PerformedadvancedexploratoryanalyticsandappliedmachinelearningalgorithmsincludingSupportVector
# Machines,neuralnetworks,andclusteringtechniquestoextractactionableinsightsfromlarge-scaledatasets.• Providedtechnicalleadershipforadvancedtechnologyprojects,coordinatingwithgloballydistributedcross-
# functionalteamstodeliverdata-drivensolutionsthatinfluencedorganizationalstrategy.
# • RecognizedwithCognizantHackathonAward(2018)forinnovativemachinelearningsolutionthatautomated
# customersentimentanalysiswith92%accuracy.
# EarlierExperience
# SoftwareEngineer-DataAnalytics,RobokidzEduventures,Pune(Sept2015-Nov2017):Designedanalyticssolution
# architectureforretailande-commerceplatformsusingApacheSolr,Scala,andHDFS.Implementedreal-timesentiment
# analysispipelinesforuserreviewdataprocessing.
# EDUCATION
# NanodegreeProgram-MachineLearningEngineerwithMicrosoftAzure |Udacity,2021
# MasterofTechnology(M.Tech)-ComputerScience&Engineering |JNTU,Hyderabad,2013-2015
# BachelorofEngineering(B.E.)-ComputerEngineering |MaharashtraInstituteofTechnology,Pune,2009-2013
# CERTIFICATIONS&PROFESSIONALDEVELOPMENT
# • AzureMachineLearningEngineerCertification- Udacity
# • SQLforDataScienceSpecialization- UniversityofCalifornia,Davis
# • AgenticAIPioneerProgram- AnalyticsVidhya
# • SQLDeveloperAssociateCertification- Fractal
# • DataAnalysisonHadoopSpecialization- LinkedIn
# PUBLICATIONS&RESEARCH
# • "CloudComputing:EnvironmentofNextGenerationTechnology"
# • "CloudComputing:DemandandSupplyinBanking,HealthcareandAgriculture"
# • "DesignApproachforVANETRoutingUsingRealTimeVehicularTrafficInformation"

# %%
with open("summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Rajan Yadav"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Rajan Yadav. You are answering questions on Rajan Yadav\'s website, particularly questions related to Rajan Yadav\'s career, background, skills and experience. Your responsibility is to represent Rajan Yadav for interactions on the website as faithfully as possible. You are given a summary of Rajan Yadav\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Rajan Yadav. I\'m an Architect and MLOps Engineer. I\'m originally from Pune, India, but I moved to Bengaluru in 2020.\nI love all foods, particularly South Indian food, but strangely I\'m repelled by almost all forms of cheese. I\'m not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\nRAJANKUMARYADAV\nMLOpsTechLead|AIArchitect|MachineLearningEngineer\nBengaluru,Karnataka,India\nLinkedIn:https://www.linkedin.com/in/rajankumaryadav/|GitHub: https://github.com/RajanKumarYadav\nPROFESSIONALSUMMARY\nResults-drivenMLOpsTechLeadandAIArchitectwith12+yearsofhands-onexperiencedesigninganddeploying\nscalable,production-grademachinelearningsystems.ProventrackrecordofdeliveringUSD2.5M+incostsavings\nthroughMLautomationandoperationalexcellence.Expertinend-to-endMLlifecyclemanagement,CI/CDpipelines,\nandcloudinfrastructure(Azure,Databricks).SpecializedinMLOps,modeldeployment,Kubernetesorchestration,andAI\ngovernance.Recognizedforreducingdeploymenttimeby90%andimprovingsystemreliabilityacrossenterprise\nenvironments.\nTECHNICALSKILLS\nMLOps&DevOps: MLOps,LLMOps,MLflow,DatabricksAssetBundles,Infrastructure-as-Code,Terraform,CI/CD(GitHub\nActions),Git,Bitbucket,Docker,Kubernetes,ModelRegistry,FeatureStores,MLObservability,ModelMonitoring\nCloud&DataPlatforms: MicrosoftAzure,AzureML,AzureDataFactory,AzureKubernetesService(AKS),Databricks,\nDeltaLiveTables,MinIO,AzureSQLDatabase,AzureDataLakeStorageGen2\nProgramming&MLFrameworks: Python,NumPy,Pandas,Scikit-learn,TensorFlow,Keras,XGBoost,Flask,FastAPI,\nRESTfulAPIs,JSON\nModelDeployment&Serving: SeldonCore,TensorFlowServing,DockerContainerization,KubernetesOrchestration,\nBatchInference,Real-timeInference,ModelVersioning,A/BTesting\nMachineLearning&AI: SupervisedLearning(Classification,Regression,NeuralNetworks,TimeSeries-ARIMA,LSTM),\nUnsupervisedLearning(Clustering,AssociationRules,DimensionalityReduction),DeepLearning,ModelOptimization,\nHyperparameterTuning,AutoML\nDataEngineering&Analytics: ETL/ELTPipelines,SQL,DataPreprocessing,FeatureEngineering,ExploratoryData\nAnalysis(EDA),DataVisualization\nLeadership&Strategy: TechnicalTeamLeadership,Cross-functionalCollaboration,StakeholderManagement,Technical\nStrategy,Agile/ScrumMethodologies,Mentoring&Training,AIGovernance\nPROFESSIONALEXPERIENCE\nArchitect-AI&MLEngineering\nFractal Analytics, Bengaluru | July 2024 - Present (1.8 years)\nClient:BlueShieldofCalifornia\n• ArchitectedandimplementedInfrastructure-as-Code(IaC)forMLworkflowsusingDatabricksAssetBundles\n(DABs),enablingversion-controlleddeploymentofMLjobs,pipelines,andresourcesacrossdevelopment,\nstaging,andproductionenvironmentswithstandardizedYAMLconfigurations.\n• Designedanddeployedmulti-environmentCI/CDpipelinearchitectureusingDatabricksAssetBundles,\norchestratingseamlesspromotionofMLassetsacrossmultipleworkspaceswhilemaintainingenvironment-\nspecificconfigurationsandensuring99.9%deploymentconsistency.\n• EstablishedmodularandreusableMLOpstemplatesforMLprojects,creatingstandardizedbestpracticesfor\nprojectstructure,resourcedefinitions,anddeploymentpatternsthatreduceddeploymenttimeby90%and\nenabledrapidteamonboarding.• ImplementedunifieddeploymentstrategyforcompleteMLsolutions,bundlingDeltaLiveTablespipelines,\nscheduledjobs,MLflowexperiments,andmodelservingendpointsasatomicunitstoensuredependency\nmanagementan ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
